# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                                     Rua               Bairro  \
# 9175                                         Rua Canumá   Jardim dos Estados
# 6272                        Avenida República do Líbano           Ibirapuera
# 3090                                         Rua Grécia        Jardim Europa
# 1893                                                NaN           Vila Sônia
# 4118                        Rua Engenheiro Isaac Milder         Vila Morumbi
# 2272                   Rua Doutor Manoel Maria Tourinho             Pacaembu
# 268   Travessa Doutor Ezequiel Antunes de Oliveira, ...  Vila Nova Conceição
# 4251                                          Rua Bauru             Pacaembu
# 130                                 Rua Bernardo Vieira            Vila Laís
# 4993                                 Rua Albina Barbosa            Aclimação
#
#          Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 9175  São Paulo       311        4          6      6
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                            Rua                 Bairro     Cidade  Metragem  \
# 2402             Rua Catuicara      Jardim Novo Mundo  São Paulo       220
# 1662                       NaN         Jardim Morumbi  São Paulo      1200
# 9920           Rua Santo André         Vila São Pedro  São Paulo        75
# 7690     Rua Cornélio Procópio                  Saúde  São Paulo       170
# 3498                       NaN        Jardim Paulista  São Paulo       844
# 8227                       NaN  Vila Brasílio Machado  São Paulo       115
# 5991  Rua Doutor Carneiro Maia        Vila Água Funda  São Paulo       138
# 8071                       NaN        Jardim Paulista  São Paulo       605
# 1808              Rua Natingui          Vila Madalena  São Paulo       305
# 6547           Avenida Itacira      Planalto Paulista  São Paulo       322
#
#       Quartos  Banheiros  Vagas          Valor
# 2402        4          5      3   R$ 2.700.000
# 1662        5          7      7   R$ 9.000.000
# ...

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/3144433095.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/3338901845.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/3338901845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# #Desafio Aula 2
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0           7000000.00
# ...

# %%
dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/2851574125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
# ...

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_m2
# Bairro
# ...

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2
# Bairro
# ...

# %%
dados_bairro["Valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2  Valor_m2_bairro
# ...

# %%
dados_vendas.groupby("Bairro").mean().loc["Vila Mariana"]
# Out:
# Metragem                  231.24
# Quartos                     3.39
# Banheiros                   3.24
# Vagas                       2.95
# Valor_anuncio_float   1771159.76
# Valor_m2                 7913.15
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor_anuncio_float   299326000.00
# Valor_m2                1337323.16
# Valor_m2_bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %%
top_bairros = dados_vendas["Bairro"].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# ...

# %%
dados_bairro.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv(ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                              86.00
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                              94.00
# ...

# %% [markdown]
# ##Desafio Aula 3
#
# - Tentar vincular dados do IBGE com os dados de imóveis.
# - Tratar os outliers e comparar com os resultados.
# - Agrupar por mais de uma categoria e realizar as análises.
# - Organize o colab para deixar com cara de projeto.

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
ibge_dados = pd.read_csv(ibge_url, sep=';', encoding='utf-8',  thousands='.', decimal=',')

# %%
# Tratar os outliers e comparar com os resultados

sem_outliers = dados_vendas[['Valor_anuncio_float', 'Metragem', 'Bairro']]
sem_outliers
# Out:
#        Valor_anuncio_float  Metragem              Bairro
# 0               7000000.00      1000   Planalto Paulista
# 1               3700000.00       496  Jardim dos Estados
# 2                380000.00       125     Jardim Reimberg
# 3                685000.00       310      Jardim Morumbi
# 4                540000.00       100               Mooca
# ...                    ...       ...                 ...
# 10002           1500000.00       267   Planalto Paulista
# 10003            665000.00        95          Vila Sofia
# 10004           2300000.00       605     Bosque da Saúde
# 10005           1050000.00       205       Vila da Saúde
# 10007            270000.00       122         Vila Alpina
#
# [9156 rows x 3 columns]

# %%
sem_outliers.sort_values(by='Metragem', ascending=False, inplace=True)
sem_outliers
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       Valor_anuncio_float  Metragem            Bairro
# 9845           7000000.00    750000    Jardim Guedala
# 6600           2900000.00     37000     Sítio Represa
# 6883           2550000.00     35677  Jardim da Glória
# 4788           4000000.00      2850      Vila Castelo
# 7791          12500000.00      2505          Pacaembu
# ...                   ...       ...               ...
# 8553            300000.00        29    Parada Inglesa
# 5059            800000.00        25  Jardim Ampliação
# 5652            800000.00        25  Jardim Ampliação
# 5009            800000.00        20  Jardim Ampliação
# ...

# %%
sem_outliers.query('Metragem < 30000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/1463703191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('Metragem < 30000', inplace=True)

# %%
sem_outliers
# Out:
#       Valor_anuncio_float  Metragem            Bairro
# 4788           4000000.00      2850      Vila Castelo
# 7791          12500000.00      2505          Pacaembu
# 7906          12500000.00      2505          Pacaembu
# 7067          12500000.00      2500          Pacaembu
# 6908          19000000.00      2200    Retiro Morumbi
# ...                   ...       ...               ...
# 8553            300000.00        29    Parada Inglesa
# 5059            800000.00        25  Jardim Ampliação
# 5652            800000.00        25  Jardim Ampliação
# 5009            800000.00        20  Jardim Ampliação
# 9603            800000.00        10        Vila Guaca
#
# [9153 rows x 3 columns]

# %%
ax = sns.boxenplot(x=sem_outliers['Valor_anuncio_float'])

# %%
sem_outliers.sort_values(by='Valor_anuncio_float', ascending=False, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers.query('Valor_anuncio_float < 50000000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/3717259412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('Valor_anuncio_float < 50000000', inplace=True)

# %%
sem_outliers
# Out:
#       Valor_anuncio_float  Metragem             Bairro
# 3542          45825000.00       773     Jardim América
# 102           37000000.00       756      Jardim Europa
# 2906          35000000.00      1400      Jardim Europa
# 8364          32000000.00       912  Jardim Petrópolis
# 5460          30000000.00      1105     Jardim América
# ...                   ...       ...                ...
# 1596            147288.00        61  Cidade São Mateus
# 2194            147288.00        61  Cidade São Mateus
# 48              130000.00       120      Jardim Amália
# 11               15000.00       436   Jardim Luzitânia
# 60               13000.00       200      Jardim Europa
#
# [9149 rows x 3 columns]

# %%
ax = sns.boxenplot(x=sem_outliers['Valor_anuncio_float'])

# %%
sem_outliers.sort_values(by='Valor_anuncio_float', ascending=True, inplace=True)
sem_outliers[:20]
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       Valor_anuncio_float  Metragem               Bairro
# 60               13000.00       200        Jardim Europa
# 11               15000.00       436     Jardim Luzitânia
# 48              130000.00       120        Jardim Amália
# 2194            147288.00        61    Cidade São Mateus
# 1596            147288.00        61    Cidade São Mateus
# 9653            160000.00        45       Vila Paranaguá
# 8415            165000.00       182           Vila Aurea
# 5345            180000.00        85  Vila Cardoso Franco
# 9316            180000.00       125  Jardim Morais Prado
# 4861            180000.00        80  Vila Cardoso Franco
# ...

# %%
sem_outliers.query('Valor_anuncio_float > 100000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/2250657400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('Valor_anuncio_float > 100000', inplace=True)

# %%
sem_outliers
# Out:
#       Valor_anuncio_float  Metragem             Bairro
# 48              130000.00       120      Jardim Amália
# 2194            147288.00        61  Cidade São Mateus
# 1596            147288.00        61  Cidade São Mateus
# 9653            160000.00        45     Vila Paranaguá
# 8415            165000.00       182         Vila Aurea
# ...                   ...       ...                ...
# 2132          30000000.00      1060    Jardim Paulista
# 8364          32000000.00       912  Jardim Petrópolis
# 2906          35000000.00      1400      Jardim Europa
# 102           37000000.00       756      Jardim Europa
# 3542          45825000.00       773     Jardim América
#
# [9147 rows x 3 columns]

# %%
ax = sns.boxenplot(x=sem_outliers['Valor_anuncio_float'])

# %%
sem_outliers.query('Valor_anuncio_float < 30000000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/823132941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('Valor_anuncio_float < 30000000', inplace=True)

# %%
sem_outliers
# Out:
#       Valor_anuncio_float  Metragem             Bairro
# 48              130000.00       120      Jardim Amália
# 2194            147288.00        61  Cidade São Mateus
# 1596            147288.00        61  Cidade São Mateus
# 9653            160000.00        45     Vila Paranaguá
# 8415            165000.00       182         Vila Aurea
# ...                   ...       ...                ...
# 9428          27000000.00       600     Jardim América
# 3300          27000000.00      1150    Jardim Paulista
# 1976          28000000.00       870     Jardim América
# 1874          28000000.00       865     Jardim América
# 5269          29780000.00       765   Jardim Luzitânia
#
# [9130 rows x 3 columns]

# %%
ax = sns.boxenplot(x=sem_outliers['Valor_anuncio_float'])

# %%
sem_outliers = dados_vendas[['Valor_anuncio_float', 'Metragem', 'Bairro', 'Valor_m2']]
sem_outliers
# Out:
#        Valor_anuncio_float  Metragem              Bairro  Valor_m2
# 0               7000000.00      1000   Planalto Paulista   7000.00
# 1               3700000.00       496  Jardim dos Estados   7459.68
# 2                380000.00       125     Jardim Reimberg   3040.00
# 3                685000.00       310      Jardim Morumbi   2209.68
# 4                540000.00       100               Mooca   5400.00
# ...                    ...       ...                 ...       ...
# 10002           1500000.00       267   Planalto Paulista   5617.98
# 10003            665000.00        95          Vila Sofia   7000.00
# 10004           2300000.00       605     Bosque da Saúde   3801.65
# 10005           1050000.00       205       Vila da Saúde   5121.95
# 10007            270000.00       122         Vila Alpina   2213.11
#
# [9156 rows x 4 columns]

# %%
sem_outliers.sort_values(by='Valor_anuncio_float', ascending=True, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers[0:20]
# Out:
#       Valor_anuncio_float  Metragem               Bairro  Valor_m2
# 60               13000.00       200        Jardim Europa     65.00
# 11               15000.00       436     Jardim Luzitânia     34.40
# 48              130000.00       120        Jardim Amália   1083.33
# 1596            147288.00        61    Cidade São Mateus   2414.56
# 2194            147288.00        61    Cidade São Mateus   2414.56
# 9653            160000.00        45       Vila Paranaguá   3555.56
# 8415            165000.00       182           Vila Aurea    906.59
# 9316            180000.00       125  Jardim Morais Prado   1440.00
# 4861            180000.00        80  Vila Cardoso Franco   2250.00
# 5345            180000.00        85  Vila Cardoso Franco   2117.65
# 6153            188682.00       107     Vila Nova Curuçá   1763.38
# 6677            188682.00       112     Vila Nova Curuçá   1684.66
# 280             190000.00        36            Vila Bela   5277.78
# ...

# %%
sem_outliers.sort_values(by='Valor_anuncio_float', ascending=False, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers[:10]
# Out:
#       Valor_anuncio_float  Metragem             Bairro  Valor_m2
# 400           65000000.00      1510      Jardim Europa  43046.36
# 1530          65000000.00      1200     Jardim América  54166.67
# 6882          65000000.00      1200     Jardim América  54166.67
# 6131          55000000.00      1816     Jardim América  30286.34
# 3542          45825000.00       773     Jardim América  59282.02
# 102           37000000.00       756      Jardim Europa  48941.80
# 2906          35000000.00      1400      Jardim Europa  25000.00
# 8364          32000000.00       912  Jardim Petrópolis  35087.72
# 2132          30000000.00      1060    Jardim Paulista  28301.89
# 5460          30000000.00      1105     Jardim América  27149.32

# %%
sem_outliers.query('20000 < Valor_anuncio_float < 50000000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/85471853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('20000 < Valor_anuncio_float < 50000000', inplace=True)

# %%
sem_outliers.sort_values(by='Valor_m2', ascending=False, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers.sort_values(by='Valor_m2', ascending=True, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers[0:10]
# Out:
#       Valor_anuncio_float  Metragem                        Bairro  Valor_m2
# 9845           7000000.00    750000                Jardim Guedala      9.33
# 6883           2550000.00     35677              Jardim da Glória     71.47
# 6600           2900000.00     37000                 Sítio Represa     78.38
# 6398            350000.00       645  Jardim Vera Cruz(Zona Leste)    542.64
# 5874            350000.00       640  Jardim Vera Cruz(Zona Leste)    546.88
# 559             295000.00       386            Jardim Vila Carrão    764.25
# 6294            450000.00       525          Jardim Nove de Julho    857.14
# 5699            450000.00       520          Jardim Nove de Julho    865.38
# 8415            165000.00       182                    Vila Aurea    906.59
# 7357            841750.00       833                  Paraisópolis   1010.50

# %%
sem_outliers.query('500 < Valor_m2 < 80000', inplace=True)
# Out:
# C:\Users\Alan\AppData\Local\Temp/ipykernel_10320/3003406696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sem_outliers.query('500 < Valor_m2 < 80000', inplace=True)

# %%
sem_outliers
# Out:
#       Valor_anuncio_float  Metragem                        Bairro  Valor_m2
# 6398            350000.00       645  Jardim Vera Cruz(Zona Leste)    542.64
# 5874            350000.00       640  Jardim Vera Cruz(Zona Leste)    546.88
# 559             295000.00       386            Jardim Vila Carrão    764.25
# 6294            450000.00       525          Jardim Nove de Julho    857.14
# 5699            450000.00       520          Jardim Nove de Julho    865.38
# ...                   ...       ...                           ...       ...
# 3308          25000000.00       581                 Jardim Europa  43029.26
# 9428          27000000.00       600                Jardim América  45000.00
# 102           37000000.00       756                 Jardim Europa  48941.80
# 7569          30000000.00       581                Jardim América  51635.11
# 3542          45825000.00       773                Jardim América  59282.02
#
# [9146 rows x 4 columns]

# %%
sem_outliers.sort_values(by='Metragem', ascending=False, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers[0:10]
# Out:
#       Valor_anuncio_float  Metragem          Bairro  Valor_m2
# 4788           4000000.00      2850    Vila Castelo   1403.51
# 7791          12500000.00      2505        Pacaembu   4990.02
# 7906          12500000.00      2505        Pacaembu   4990.02
# 7067          12500000.00      2500        Pacaembu   5000.00
# 7478          19000000.00      2200  Retiro Morumbi   8636.36
# 6908          19000000.00      2200  Retiro Morumbi   8636.36
# 7026          19800000.00      2200  Retiro Morumbi   9000.00
# 1936           4900000.00      2165        Tucuruvi   2263.28
# 1842           4900000.00      2160        Tucuruvi   2268.52
# 2508          19800000.00      2100  Retiro Morumbi   9428.57

# %%
sem_outliers.sort_values(by='Metragem', ascending=True, inplace=True)
# Out:
# C:\Users\Alan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
sem_outliers[0:10]
# Out:
#       Valor_anuncio_float  Metragem            Bairro  Valor_m2
# 5009            800000.00        20  Jardim Ampliação  40000.00
# 5652            800000.00        25  Jardim Ampliação  32000.00
# 5059            800000.00        25  Jardim Ampliação  32000.00
# 8553            300000.00        29    Parada Inglesa  10344.83
# 7053            196000.00        36         Vila Bela   5444.44
# 9661            200000.00        36         Vila Bela   5555.56
# 280             190000.00        36         Vila Bela   5277.78
# 2054            690000.00        37       Santo Amaro  18648.65
# 5426            259692.00        37  Vila Santa Maria   7018.70
# 7313            510000.00        37              Lapa  13783.78

# %%
import seaborn as sns

# %%
m2 = dados_vendas[['Bairro', 'Metragem', 'Valor_anuncio_float']].groupby('Bairro', as_index=False).sum()
m2['valor_m2'] = m2['Valor_anuncio_float']/m2['Metragem']
m2.sort_values(by='valor_m2', ascending=False, inplace=True)

# %%
sns.set()
plt.figure(figsize=(10, 8))
ax = sns.barplot(data = m2[:20], x = 'valor_m2', y='Bairro', orient='h')
ax.set_title('Os 20 metros quadrados mais caros em São Paulo')
plt.xlabel('Valor do metro quadrado')
plt.show()

# %%
dados_sem_outliers = sem_outliers[['Bairro', 'Metragem', 'Valor_anuncio_float']].groupby('Bairro', as_index=False).sum()
dados_sem_outliers['valor_m2'] = dados_sem_outliers['Valor_anuncio_float']/dados_sem_outliers['Metragem']
dados_sem_outliers.sort_values(by='valor_m2', ascending=False, inplace=True)

# %%
dados_sem_outliers
# Out:
#                            Bairro  Metragem  Valor_anuncio_float  valor_m2
# 103                Jardim América     72695        1769884000.00  24346.71
# 277                 Jardim Teresa      1945          44510000.00  22884.32
# 155                 Jardim Europa    117188        2349159900.00  20046.08
# 595           Vila Nova Conceição     27837         489265000.00  17576.07
# 334            Morro dos Ingleses      1400          24300000.00  17357.14
# ..                            ...       ...                  ...       ...
# 214          Jardim Nove de Julho      1245           1400000.00   1124.50
# 120  Jardim Brasília (Zona Leste)       910            960000.00   1054.95
# 177             Jardim Itapemirim       204            215118.00   1054.50
# 452                    Vila Aurea       182            165000.00    906.59
# 290  Jardim Vera Cruz(Zona Leste)      1285            700000.00    544.75
#
# [695 rows x 4 columns]

# %%
sns.set()
plt.figure(figsize=(10, 8))
ax = sns.barplot(data = dados_sem_outliers[:20], x = 'valor_m2', y='Bairro', orient='h')
ax.set_title('Os 20 metros quadrados mais caros em São Paulo - Sem outliers')
plt.xlabel('Valor do metro quadrado')
plt.show()

# %%
ibge_url
# Out:
# 'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv'

# %%
ibge_url
# Out:
# 'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv'

# %%
ibge_dados['Nome_Grande_Regiao']
# Out:
#              Cod_setor  Cod_Grandes Regi�es Nome_Grande_Regiao  Cod_UF  \
# 0      355030801000001                    3     Regi�o Sudeste      35
# 1      355030801000002                    3     Regi�o Sudeste      35
# 2      355030801000003                    3     Regi�o Sudeste      35
# 3      355030801000004                    3     Regi�o Sudeste      35
# 4      355030801000005                    3     Regi�o Sudeste      35
# ...                ...                  ...                ...     ...
# 18358  355030896000243                    3     Regi�o Sudeste      35
# 18359  355030896000244                    3     Regi�o Sudeste      35
# 18360  355030896000245                    3     Regi�o Sudeste      35
# 18361  355030896000246                    3     Regi�o Sudeste      35
# 18362  355030896000247                    3     Regi�o Sudeste      35
#
#       Nome_da_UF   Cod_meso                Nome_da_meso  Cod_micro  \
# ...

# %%
ibge_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_setor            18363 non-null  int64
#  1   Cod_Grandes Regi�es  18363 non-null  int64
#  2   Nome_Grande_Regiao   18363 non-null  object
#  3   Cod_UF               18363 non-null  int64
#  4   Nome_da_UF           18363 non-null  object
#  5   Cod_meso             18363 non-null  int64
#  6   Nome_da_meso         18363 non-null  object
#  7   Cod_micro            18363 non-null  int64
#  8   Nome_da_micro        18363 non-null  object
#  9   Cod_RM               18363 non-null  int64
#  10  Nome_da_RM           18363 non-null  object
#  11  Cod_municipio        18363 non-null  int64
#  12  Nome_do_municipio    18363 non-null  object
#  13  Cod_distrito         18363 non-null  int64
#  14  Nome_do_distrito     18363 non-null  object
# ...
